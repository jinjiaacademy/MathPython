# %% [markdown]
# # Algebra BUG HUNT!

# %%
# create a list
lst = [1, 3, 4, 1, 6]

print( lst )
# Out:
# [1, 3, 4, 1, 6]

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
from IPython.display import display, Math
import scipy as sp

# add all the numbers together
print( np.sum(lst) )
# Out:
# 15

# %%
# plot the cumulative sum of a list of numbers
l = np.arange(-4,10)

plt.plot(l,'rs-')
plt.plot(np.cumsum(l),'bo-')
plt.legend({'list','cumsum'})
plt.show()

# %%
### the equation:
# 4 - 2x + 5x^3

# define the coefficients
coefs = [5,0,-2,4]

# solve
roots = np.roots(coefs)

# and display
from sympy.abc import x

p = sym.Poly(coefs,x)

display(Math(sym.latex(p)))
# Out:
# $\displaystyle \operatorname{Poly}{\left( 5 x^{3} - 2 x + 4, x, domain=\mathbb{Z} \right)}$

# %%
def quadeq(a,b,c):
    out = [0, 0]
    # compute
    out[0] = ( -b - sp.sqrt(b**2 - 4*a*c) ) / (2*a)
    out[1] = ( -b + sp.sqrt(b**2 - 4*a*c) ) / (2*a)
    
    # output
    return out

# test the function
print(quadeq(1,4,2))
# Out:
# [-3.414213562373095, -0.5857864376269049]
# C:\Users\Ruixin Li\AppData\Local\Temp\ipykernel_1408\1419386380.py:4: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#   out[0] = ( -b - sp.sqrt(b**2 - 4*a*c) ) / (2*a)
# C:\Users\Ruixin Li\AppData\Local\Temp\ipykernel_1408\1419386380.py:5: DeprecationWarning: scipy.sqrt is deprecated and will be removed in SciPy 2.0.0, use numpy.lib.scimath.sqrt instead
#   out[1] = ( -b + sp.sqrt(b**2 - 4*a*c) ) / (2*a)

# %%
# create a complex number

real_part = 4
imag_part = -6

cn = np.complex(imag_part,real_part)

plt.plot(np.real(cn),np.imag(cn),'ro')
plt.grid('on')
plt.axis('square')
plt.axis([-10,10,-10,10])
plt.show()
# Out:
# C:\Users\Ruixin Li\AppData\Local\Temp\ipykernel_1408\1924029566.py:6: DeprecationWarning: `np.complex` is a deprecated alias for the builtin `complex`. To silence this warning, use `complex` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.complex128` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   cn = np.complex(imag_part,real_part)

# %%
# symbolic complex number
a,b = sym.symbols('a,b',real=True)

z = a + b*sym.I
display(Math('z\\times z^* = %s' %sym.latex(sym.expand(z*sym.conjugate(z)))))
# Out:
# $\displaystyle z\times z^* = a^{2} + b^{2}$

# %%
# define the phase angles
x = np.linspace(0,2*np.pi,100)

# generate the plot
plt.plot(np.cos(x),np.sin(x),'k')

# draw one vector from the origin
phs = 1*np.pi/4
plt.plot([0,np.cos(phs)],[0,np.sin(phs)],'r-')
plt.plot(np.cos(phs),np.sin(phs),'ro')


# draw axis lines
plt.plot([-1.3,1.3],[0,0],'--',color=[.8,.8,.8])
plt.plot([0,0],[-1.3,1.3],'--',color=[.8,.8,.8])

# make it look nicer
plt.axis('square')
plt.axis([-1.3,1.3,-1.3,1.3])
plt.xlabel('cosine(x)')
plt.ylabel('sine(x)')
plt.plot()

plt.show()

# %%
a =   2 # lower bound
b = 100 # upper bound
n =   3 # number of steps

lo = np.logspace(np.log10(a),np.log10(b), n)
li = np.linspace(a,b, n)

plt.plot(li,lo,'s-',label='log')
plt.plot(li,li,'o-',label='linear')

plt.legend()
plt.axis('square')
plt.show()

# %%
## Goal is to plot the point on the function closest to f(x)=.5


# x range
x = np.linspace(-6,10,20)

# the function f(x)
fx = 1/(1+np.exp(x))

# function maximum
fmaxidx = np.argmin(abs(fx-.5))

# draw the function
plt.plot(x,fx,'bo-')
plt.plot(x[fmaxidx],fx[fmaxidx],'rs')

plt.show()

# %%
## Goal is to find the local minima by adding one character

from scipy.signal import find_peaks

# x range
x = np.linspace(0,12*np.pi,200)

# the function f(x)
fx = -( np.cos(x) + x**(1/2) )

# find peaks
peeks = find_peaks(-fx)

# draw the function
plt.plot(x,fx)
plt.plot(x[peeks[0]],fx[peeks[0]],'o')
plt.show()
